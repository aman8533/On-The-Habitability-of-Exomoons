# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import sympy as smp
import math
from scipy import integrate as integrate

G = 6.672 * 10**(-11)
SB_Constant = 5.67 * 10**(-8)
L_sol = 0.489

def Elliptical_integral(Eccentricity): 
    def f(t,a):
        return ((1-(2*a*t**2 / (1+a))) / (1-t**2))**(1/2)
    value,error = integrate.quad(f,0,1,args=(Eccentricity))
    return value


def Orbital_distance(Semi_major_axis, Eccentricity):
    Orbital_distance = Semi_major_axis * (1 + (Eccentricity**2 / 2))
    return Orbital_distance

def Stellar_flux(Luminosity, Semi_major_axis, Eccentricity):
    Stellar_flux = Luminosity / (Semi_major_axis**2 * (1 - Eccentricity**2)**(1/2))
    return Stellar_flux


def Equilibrium_temp(Albedo, Luminosity, Heat_redistribution, Eccentricity, Emmisivity, Semi_major_axis):
    Equilibrium_temp = 278.5 * ((1-Albedo) * Luminosity / (Heat_redistribution * Emmisivity * Semi_major_axis**2))**(1/4) * 2*(1+Eccentricity)**(1/2) / np.pi * Elliptical_integral(Eccentricity)
    return Equilibrium_temp

def Effective_thermal_distance(Semi_major_axis,Eccentricity):
    Effective_thermal_distance = Semi_major_axis*((2*(1+Eccentricity)**1/2) / (np.pi)) * Elliptical_integral(Eccentricity)
    return Effective_thermal_distance

# Moon

# Albedo 0.12
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.0549
# Emmisivity 1
# Semi_major_axis 0.00257
Moon_Equilibrium_Temp = Equilibrium_temp(0.11,1,1,0.0549, 1, 1.00000261)

# Deimos

# Albedo 0.06
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.00033
# Emmisivity 1
# Semi_major_axis 0.0001568418046
Deimos_Equilibrium_Temp = Equilibrium_temp(0.068,1,1,0.00033, 1, 1.5236623284371)

# Phobos

# Albedo 0.071
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.0151
# Emmisivity 1
# Semi_major_axis 1.5236623284371
Phobos_Equilibrium_Temp = Equilibrium_temp(0.071,1,1,0.0151, 1, 1.5236623284371)

# Ganymede

# Albedo 0.43
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.0013
# Emmisivity 1
# Semi_major_axis 0.007155182056
Ganymede_Equilibrium_Temp = Equilibrium_temp(0.43,1,1,0.0013, 1, 5.203362964711)

# Callisto

# Albedo 0.22
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.0074
# Emmisivity 1
# Semi_major_axis 0.012585072175
Callisto_Equilibrium_Temp = Equilibrium_temp(0.22,1,1,0.0074, 1, 5.203362964711)

# Io

# Albedo 0.63
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.0041
# Emmisivity 1
# Semi_major_axis 0.00281889039
Io_Equilibrium_Temp = Equilibrium_temp(0.63,1,1,0.0041, 1, 5.203362964711)

# Europa

# Albedo 0.67
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.009
# Emmisivity 1
# Semi_major_axis 0.0044846895
Europa_Equilibrium_Temp = Equilibrium_temp(0.67,1,1,0.009, 1, 5.203362964711)

# Titan

# Albedo 0.22
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.0288
# Emmisivity 1
# Semi_major_axis 0.008167696467
Titan_Equilibrium_Temp = Equilibrium_temp(0.22,1,1,0.0288, 1, 9.5370702358533)

# Rhea

# Albedo 0.949
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.0012583
# Emmisivity 1
# Semi_major_axis 0.003523499349
Rhea_Equilibrium_Temp = Equilibrium_temp(0.949,1,0.5,0.0012583, 1, 9.5370702358533)


# Enceladus

# Albedo 1.375
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.0047
# Emmisivity 1
# Semi_major_axis 0.00159058414
Enceladus_Equilibrium_Temp = Equilibrium_temp(1.375,1,0.5,0.0047, 1, 9.5370702358533)

# Phoebe

# Albedo 	0.06
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.1562415
# Emmisivity 1
# Semi_major_axis 0.086632249105
Phoebe_Equilibrium_Temp = Equilibrium_temp(0.06,1,0.5,0.1562415, 1,9.5370702358533)

# Amalthea

# Albedo 	0.06
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.1562415
# Emmisivity 1
# Semi_major_axis 0.086632249105
Amalthea_Equilibrium_Temp = Equilibrium_temp(0.09,1,0.5,0.00613, 1, 5.203362964711)

# Himalia

# Albedo 	0.06
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.1562415
# Emmisivity 1
# Semi_major_axis 0.086632249105
Himalia_Equilibrium_Temp = Equilibrium_temp(0.04,1,0.5,0.166, 1, 5.203362964711)

# Elara

# Albedo 	0.06
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.1562415
# Emmisivity 1
# Semi_major_axis 0.086632249105
Elara_Equilibrium_Temp = Equilibrium_temp(0.03,1,0.5,0.207, 1,5.203362964711)

# Pasiphae

# Albedo 	0.06
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.1562415
# Emmisivity 1
# Semi_major_axis 0.086632249105
Pasiphae_Equilibrium_Temp = Equilibrium_temp(0.03,1,0.5,0.207, 1,5.203362964711)

# Thebe

# Albedo 	0.06
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.1562415
# Emmisivity 1
# Semi_major_axis 0.086632249105
Thebe_Equilibrium_Temp = Equilibrium_temp(0.047,1,0.5,0.015, 1,5.203362964711)

# Mimas

# Albedo 	0.06
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.1562415
# Emmisivity 1
# Semi_major_axis 0.086632249105
Mimas_Equilibrium_Temp = Equilibrium_temp(0.047,1,0.5,0.015, 1, 9.5370702358533)

# Tethys

# Albedo 	0.06
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.1562415
# Emmisivity 1
# Semi_major_axis 0.086632249105
Tethys_Equilibrium_Temp = Equilibrium_temp(0.047,1,0.5,0.015, 1,9.5370702358533)

# Dione

# Albedo 	0.06
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.1562415
# Emmisivity 1
# Semi_major_axis 0.086632249105
Dione_Equilibrium_Temp = Equilibrium_temp(0.6,1,0.5,0.0022, 1,9.5370702358533)

# Hyperion

# Albedo 	0.06
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.1562415
# Emmisivity 1
# Semi_major_axis 0.086632249105
Hyperion_Equilibrium_Temp = Equilibrium_temp(0.25,1,0.5,0.0232, 1,9.5370702358533)

# Atlas

# Albedo 	0.06
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.1562415
# Emmisivity 1
# Semi_major_axis 0.086632249105
Atlas_Equilibrium_Temp = Equilibrium_temp(0.5,1,0.5,0, 1,9.5370702358533)

# Pandora

# Albedo 	0.06
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.1562415
# Emmisivity 1
# Semi_major_axis 0.086632249105
Pandora_Equilibrium_Temp = Equilibrium_temp(0.5,1,0.5,0.0042, 1,9.5370702358533)

# Ariel

# Albedo 	0.06
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.1562415
# Emmisivity 1
# Semi_major_axis 0.086632249105
Ariel_Equilibrium_Temp = Equilibrium_temp(0.34,1,0.5,0.0034, 1,9.5370702358533)

# Titania

# Albedo 	0.06
# Luminosity 1
# Heat_redistribution 0.5
# Eccentricity 0.1562415
# Emmisivity 1
# Semi_major_axis 0.086632249105
Titania_Equilibrium_Temp = Equilibrium_temp(0.27,1,0.5,0.0022, 1,19.1885)

print(Moon_Equilibrium_Temp)
Eccentricity = [0.0549, 0.00033, 0.0151, 0.0013, 0.0074, 0.0041, 0.009, 0.0288, 0.0012583, 0.0047, 0.1562415, 0.00613, 0.166]
Equilibrium_Temperature = [Moon_Equilibrium_Temp, Deimos_Equilibrium_Temp, Phobos_Equilibrium_Temp, Ganymede_Equilibrium_Temp, Callisto_Equilibrium_Temp, Io_Equilibrium_Temp, Europa_Equilibrium_Temp, Titan_Equilibrium_Temp, Rhea_Equilibrium_Temp, Enceladus_Equilibrium_Temp, Phoebe_Equilibrium_Temp, Amalthea_Equilibrium_Temp, Himalia_Equilibrium_Temp, Elara_Equilibrium_Temp, Pasiphae_Equilibrium_Temp, Thebe_Equilibrium_Temp, Mimas_Equilibrium_Temp, Tethys_Equilibrium_Temp, Dione_Equilibrium_Temp, Hyperion_Equilibrium_Temp, Atlas_Equilibrium_Temp, Pandora_Equilibrium_Temp]

plt.scatter(Eccentricity, Equilibrium_Temperature)
plt.xlabel("Eccentricity")
plt.ylabel("Equilibrium Temperature(K)")
# Out:
# 270.4520379421808
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-85f6c20a25d0> in <module>
#     279 Equilibrium_Temperature = [Moon_Equilibrium_Temp, Deimos_Equilibrium_Temp, Phobos_Equilibrium_Temp, Ganymede_Equilibrium_Temp, Callisto_Equilibrium_Temp, Io_Equilibrium_Temp, Europa_Equilibrium_Temp, Titan_Equilibrium_Temp, Rhea_Equilibrium_Temp, Enceladus_Equilibrium_Temp, Phoebe_Equilibrium_Temp, Amalthea_Equilibrium_Temp, Himalia_Equilibrium_Temp, Elara_Equilibrium_Temp, Pasiphae_Equilibrium_Temp, Thebe_Equilibrium_Temp, Mimas_Equilibrium_Temp, Tethys_Equilibrium_Temp, Dione_Equilibrium_Temp, Hyperion_Equilibrium_Temp, Atlas_Equilibrium_Temp, Pandora_Equilibrium_Temp]
#     280
# --> 281 plt.scatter(Eccentricity, Equilibrium_Temperature)
#     282 plt.xlabel("Eccentricity")
#     283 plt.ylabel("Equilibrium Temperature(K)")
#
# ...

# %%
# !which python
# Out:
# /Users/amanburman/opt/anaconda3/bin/python
